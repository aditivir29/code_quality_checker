# %%
import importlib
import src.report_generator as report_generator

# Force reload to get the updated version
importlib.reload(report_generator)

# Now import the functions
from src.report_generator import save_report, save_html_report

# %%
# imports
from src.pep8_checker import check_pep8
from src.syntax_checker import check_syntax
from src.scoring import calculate_score
from src.suggestions import generate_suggestions
from src.visualizer import visualize_issues
from src.report_generator import save_report, save_html_report
from src.features import analyze_complexity

import os

filepath = "data/sample.py"
print(f"📂 Analyzing file: {filepath}")

# PEP8 & syntax
pep8_result = check_pep8(filepath)
syntax_result = check_syntax(filepath)
score = calculate_score(pep8_result, syntax_result)
suggestions = generate_suggestions(pep8_result, syntax_result)

print("\n=== Analysis Results ===")
print(f"PEP8 Violations: {pep8_result['violations']}")
print(f"Syntax Errors: {syntax_result['errors']}")
print(f"Score: {score}/10")

print("\n=== Suggestions ===")
if suggestions:
    for s in suggestions:
        print("👉", s)
else:
    print("✅ No suggestions needed. Code looks clean!")

# Visualization
visualize_issues(pep8_result, syntax_result)

# Save initial reports
os.makedirs("reports", exist_ok=True)
report_data = {
    "pep8": pep8_result,
    "syntax": syntax_result,
    "score": score,
    "suggestions": suggestions
}
save_report("reports/analysis_report.json", report_data)
save_html_report("reports/analysis_report.html", report_data, pep8_result, syntax_result)

# Complexity analysis
print("\n=== Cyclomatic Complexity & Maintainability Index ===")
if syntax_result["errors"] > 0:
    print("⏩ Skipping complexity analysis due to syntax errors.")
    complexity_result = None
else:
    complexity_result = analyze_complexity(filepath)
    if "error" in complexity_result:
        print(f"⏩ Complexity analysis error: {complexity_result['error']}")
    else:
        for item in complexity_result["cyclomatic_complexity"]:
            warning = " ⚠️ High complexity!" if item['complexity'] > 10 else ""
            print(f"Function {item['name']} (line {item['lineno']}): Complexity = {item['complexity']}{warning}")
        print(f"\nMaintainability Index: {complexity_result['maintainability_index']:.2f}")

# Final summary
print("\n=== Final Summary ===")
print(f"📂 File: {filepath}")
print(f"🔹 PEP8 Violations: {pep8_result['violations']}")
print(f"🔹 Syntax Errors: {syntax_result['errors']}")
print(f"🔹 Score: {score}/10")
if complexity_result and "error" not in complexity_result:
    for item in complexity_result["cyclomatic_complexity"]:
        warning = " ⚠️ High complexity!" if item['complexity'] > 10 else ""
        print(f"    • {item['name']} (line {item['lineno']}): {item['complexity']}{warning}")
    print(f"🔹 Maintainability Index: {complexity_result['maintainability_index']:.2f}")

# Save complexity to reports
report_data["complexity"] = complexity_result
save_report("reports/analysis_report.json", report_data)
save_html_report("reports/analysis_report.html", report_data, pep8_result, syntax_result)
# Out:
# 📂 Analyzing file: data/sample.py
# data/sample.py:6:1: E302 expected 2 blank lines, found 1
# data/sample.py:12:1: E302 expected 2 blank lines, found 1
# data/sample.py:20:1: E302 expected 2 blank lines, found 1
# data/sample.py:34:1: E302 expected 2 blank lines, found 1
#
# === Analysis Results ===
# PEP8 Violations: 4
# Syntax Errors: 0
# Score: 9.6/10
#
# === Suggestions ===
# 👉 PEP8: {'line': 6, 'col': 0, 'code': 'E302', 'msg': 'E302 expected 2 blank lines, found 1'}
# 👉 PEP8: {'line': 12, 'col': 0, 'code': 'E302', 'msg': 'E302 expected 2 blank lines, found 1'}
# 👉 PEP8: {'line': 20, 'col': 0, 'code': 'E302', 'msg': 'E302 expected 2 blank lines, found 1'}
# 👉 PEP8: {'line': 34, 'col': 0, 'code': 'E302', 'msg': 'E302 expected 2 blank lines, found 1'}
#
# 📊 Generating visualizations...
# === Cyclomatic Complexity & Maintainability Index ===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 65
#      62 else:
#      63     # Print numeric values
#      64     for item in complexity_result["cyclomatic_complexity"]:
# ---> 65         warning = " ⚠️ High complexity!" if item['complexity'] > 10 else ""
#      66         print(f"Function {item['name']} (line {item['lineno']}): Complexity = {item['complexity']}{warning}")
#      68     print(f"\nMaintainability Index: {complexity_result['maintainability_index']:.2f}")
#
# TypeError: string indices must be integers, not 'str'
